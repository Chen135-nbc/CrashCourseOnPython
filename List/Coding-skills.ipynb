# %%
# Skill Group 1
# Use a for loop to modify elements of a list.
# Use the list.append() method.
# Use the string.endswith() and string.replace() methods 
# to modify the elements within a list.
years = ["January 2023", "May 2025", "April 2023", "August 2024", "September 2025", "December 2023"]
updated_years =[]
for year in years:
    if year.endswith("2023"):
        new = year.replace("2023","2024")
        updated_years.append(new)
    else:
        updated_years.append(year)

print(updated_years)
# Out:
# ['January 2024', 'May 2025', 'April 2024', 'August 2024', 'September 2025', 'December 2024']
