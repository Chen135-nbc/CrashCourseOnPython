# %%
# Skill Group 1
# Use a for loop to modify elements of a list.
# Use the list.append() method.
# Use the string.endswith() and string.replace() methods 
# to modify the elements within a list.
years = ["January 2023", "May 2025", "April 2023", "August 2024", "September 2025", "December 2023"]
updated_years =[]
for year in years:
    if year.endswith("2023"):
        new = year.replace("2023","2024")
        updated_years.append(new)
    else:
        updated_years.append(year)

print(updated_years)
# Out:
# ['January 2024', 'May 2025', 'April 2024', 'August 2024', 'September 2025', 'December 2024']

# %%
# Skill Group2
# Use a list comprehension to return values
def squares(start,end):
    return [ n*n for n in range (start,end+1)]

print(squares(2,3))
print(squares(1,5))
print(squares(0,10))
# Out:
# [4, 9]
# [1, 4, 9, 16, 25]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
# Skill Group 3
# Use a list comprehension to modify elements of a list.
# Use the string.replace() method within a list comprehension.
# Use the string[index] method within a list comprehension.

years = ["January 2023", "May 2025", "April 2023", "August 2024", "September 2025", "December 2023"]

updated_years = [year.replace("2023","2024") if year[-4:] == "2023" else year for year in years ]
print(updated_years)
# Out:
# ['January 2024', 'May 2025', 'April 2024', 'August 2024', 'September 2025', 'December 2024']

# %%
#Skill Group4
# 使用string.split()方法将字符串拆分成单个单词的列表。
# 使用 for 循环遍历新列表。
# 修改列表中的每个元素，方法是在给定的 [1:] 索引位置对元素的字符串进行切片，并将子字符串附加到元素的末尾。
# 将列表转换回字符串。
def change_string(given_string):
    new_string = ""
    new_list = given_string.split()
    for element in new_list:
        new_string += element[1:] + "-" + element[0] + " "
        
    return new_string
print(change_string("1one 2two 3three 4four 5five"))
# Out:
# one-1 two-2 three-3 four-4 five-5

# %%
#Skill Group5
# Use the string.join() method to concatenate a string that provides a list name and its elements.

def list_elements(list_name,element):
    return "The " + list_name + " list includes:" + ",".join(element)
print(list_elements("Printers", ["Color Printer", "Black and White Printer", "3-D Printer"]))
# Out:
# The Printers list includes:Color Printer,Black and White Printer,3-D Printer

# %%
#Skill Group6
# Use map() and convert the map object to a list so we can print all the results at once.
# map 用来把“一个函数”应用到“可迭代对象(比如列表)的每个元素上”，生成一个新的可迭代结果。
def add_one(number):
    return number + 1
numbers = [1,2,3,4,5]
result = map(add_one,numbers)
print(list(result))
# Out:
# [2, 3, 4, 5, 6]

# %%
# Skill Group 7
# Use zip() to combine a list of names and ages into a list of tuples, and print all the tuples at once.
names = ["Alice", "Bob", "Charlie"]
ages = [25,30,35]
combined = zip(names,ages)
print(list(combined))
# Out:
# [('Alice', 25), ('Bob', 30), ('Charlie', 35)]
